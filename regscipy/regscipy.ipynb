# %% [markdown]
# # Adding Regression Lines to Pandas Plots with SciPy
#
# ## Regression can be used to predict the future or to identify trends and relationships in data

# %%
import pandas as pd
from scipy import stats

# %%
weather = pd.read_csv('https://raw.githubusercontent.com/alanjones2/dataviz/master/londonweather.csv')
july = weather.query('Month == 7')[['Year','Tmax']]
july.plot.scatter(y='Tmax',x='Year', figsize = (16,8))
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Tmax'>

# %%
x = july['Year']
y = july['Tmax']

m = stats.linregress(x, y)

t = [m.slope * i + m.intercept for i in x]

july.insert(len(july.columns),'trend',t)

ax = july.plot.scatter(x='Year',y='Tmax')
july.plot.line(x='Year',y='trend', color='red', ax=ax, figsize = (16,8))

#july
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Tmax'>

# %%
gdpdata = pd.read_csv('https://github.com/alanjones2/stGDPG7/raw/main/QNA_26022022111050612.csv')
gdpdata.head()
# Out:
#   LOCATION Country SUBJECT                                        Subject  \
# 0      CAN  Canada   B1_GE  Gross domestic product - expenditure approach
# 1      CAN  Canada   B1_GE  Gross domestic product - expenditure approach
# 2      CAN  Canada   B1_GE  Gross domestic product - expenditure approach
# 3      CAN  Canada   B1_GE  Gross domestic product - expenditure approach
# 4      CAN  Canada   B1_GE  Gross domestic product - expenditure approach
#
#   MEASURE                                            Measure FREQUENCY  \
# 0    GPSA  Growth rate based on seasonally adjusted volum...         Q
# 1    GPSA  Growth rate based on seasonally adjusted volum...         Q
# 2    GPSA  Growth rate based on seasonally adjusted volum...         Q
# 3    GPSA  Growth rate based on seasonally adjusted volum...         Q
# 4    GPSA  Growth rate based on seasonally adjusted volum...         Q
#
#    Frequency     TIME   Period Unit Code        Unit  PowerCode Code  \
# 0  Quarterly  2007-Q1  Q1-2007        PC  Percentage               0
# 1  Quarterly  2007-Q2  Q2-2007        PC  Percentage               0
# 2  Quarterly  2007-Q3  Q3-2007        PC  Percentage               0
# 3  Quarterly  2007-Q4  Q4-2007        PC  Percentage               0
# 4  Quarterly  2008-Q1  Q1-2008        PC  Percentage               0
#
#   PowerCode  Reference Period Code  Reference Period     Value Flag Codes  \
# 0     Units                    NaN               NaN  0.639627        NaN
# 1     Units                    NaN               NaN  0.968907        NaN
# 2     Units                    NaN               NaN  0.419855        NaN
# 3     Units                    NaN               NaN  0.113617        NaN
# 4     Units                    NaN               NaN  0.076641        NaN
#
#   Flags
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
G7data = gdpdata[(gdpdata['MEASURE']=='VIXOBSA') 
        & (gdpdata['Country']=='G7')]
        
G7data=G7data[['Period','Value']]
G7data
# Out:
#        Period  Value
# 1260  Q1-2007   92.4
# 1261  Q2-2007   92.9
# 1262  Q3-2007   93.2
# 1263  Q4-2007   93.6
# 1264  Q1-2008   93.7
# 1265  Q2-2008   93.8
# 1266  Q3-2008   93.1
# 1267  Q4-2008   91.2
# 1268  Q1-2009   89.1
# 1269  Q2-2009   89.2
# 1270  Q3-2009   89.4
# 1271  Q4-2009   90.3
# 1272  Q1-2010   90.8
# 1273  Q2-2010   91.8
# 1274  Q3-2010   92.6
# 1275  Q4-2010   93.0
# 1276  Q1-2011   93.1
# 1277  Q2-2011   93.3
# 1278  Q3-2011   93.8
# 1279  Q4-2011   94.2
# 1280  Q1-2012   94.8
# 1281  Q2-2012   94.9
# 1282  Q3-2012   95.0
# 1283  Q4-2012   94.9
# 1284  Q1-2013   95.5
# 1285  Q2-2013   95.9
# 1286  Q3-2013   96.6
# 1287  Q4-2013   97.0
# 1288  Q1-2014   97.2
# 1289  Q2-2014   97.6
# 1290  Q3-2014   98.4
# 1291  Q4-2014   98.8
# 1292  Q1-2015   99.4
# 1293  Q2-2015   99.9
# 1294  Q3-2015  100.2
# 1295  Q4-2015  100.4
# 1296  Q1-2016  101.0
# 1297  Q2-2016  101.2
# 1298  Q3-2016  101.7
# 1299  Q4-2016  102.2
# 1300  Q1-2017  102.8
# 1301  Q2-2017  103.4
# 1302  Q3-2017  104.1
# 1303  Q4-2017  104.9
# 1304  Q1-2018  105.3
# 1305  Q2-2018  106.0
# 1306  Q3-2018  106.2
# 1307  Q4-2018  106.5
# 1308  Q1-2019  107.1
# 1309  Q2-2019  107.6
# 1310  Q3-2019  108.1
# 1311  Q4-2019  107.9
# 1312  Q1-2020  105.9
# 1313  Q2-2020   94.9
# 1314  Q3-2020  103.8
# 1315  Q4-2020  104.8
# 1316  Q1-2021  105.3
# 1317  Q2-2021  107.2
# 1318  Q3-2021  108.2
# 1319  Q4-2021  109.5

# %%
def formyr(x,data):
    d = data['Period'].values[x]
    y= int(d[-4:])+int(d[1:2])*0.25 - 2007
    return y   

yr=[formyr(x,G7data) for x in range(len(G7data)) ]
G7data['yr'] = yr
G7data
# Out:
#        Period  Value     yr
# 1260  Q1-2007   92.4   0.25
# 1261  Q2-2007   92.9   0.50
# 1262  Q3-2007   93.2   0.75
# 1263  Q4-2007   93.6   1.00
# 1264  Q1-2008   93.7   1.25
# 1265  Q2-2008   93.8   1.50
# 1266  Q3-2008   93.1   1.75
# 1267  Q4-2008   91.2   2.00
# 1268  Q1-2009   89.1   2.25
# 1269  Q2-2009   89.2   2.50
# 1270  Q3-2009   89.4   2.75
# 1271  Q4-2009   90.3   3.00
# 1272  Q1-2010   90.8   3.25
# 1273  Q2-2010   91.8   3.50
# 1274  Q3-2010   92.6   3.75
# 1275  Q4-2010   93.0   4.00
# 1276  Q1-2011   93.1   4.25
# 1277  Q2-2011   93.3   4.50
# 1278  Q3-2011   93.8   4.75
# 1279  Q4-2011   94.2   5.00
# 1280  Q1-2012   94.8   5.25
# 1281  Q2-2012   94.9   5.50
# 1282  Q3-2012   95.0   5.75
# 1283  Q4-2012   94.9   6.00
# 1284  Q1-2013   95.5   6.25
# 1285  Q2-2013   95.9   6.50
# 1286  Q3-2013   96.6   6.75
# 1287  Q4-2013   97.0   7.00
# 1288  Q1-2014   97.2   7.25
# 1289  Q2-2014   97.6   7.50
# 1290  Q3-2014   98.4   7.75
# 1291  Q4-2014   98.8   8.00
# 1292  Q1-2015   99.4   8.25
# 1293  Q2-2015   99.9   8.50
# 1294  Q3-2015  100.2   8.75
# 1295  Q4-2015  100.4   9.00
# 1296  Q1-2016  101.0   9.25
# 1297  Q2-2016  101.2   9.50
# 1298  Q3-2016  101.7   9.75
# 1299  Q4-2016  102.2  10.00
# 1300  Q1-2017  102.8  10.25
# 1301  Q2-2017  103.4  10.50
# 1302  Q3-2017  104.1  10.75
# 1303  Q4-2017  104.9  11.00
# 1304  Q1-2018  105.3  11.25
# 1305  Q2-2018  106.0  11.50
# 1306  Q3-2018  106.2  11.75
# 1307  Q4-2018  106.5  12.00
# 1308  Q1-2019  107.1  12.25
# 1309  Q2-2019  107.6  12.50
# 1310  Q3-2019  108.1  12.75
# 1311  Q4-2019  107.9  13.00
# 1312  Q1-2020  105.9  13.25
# 1313  Q2-2020   94.9  13.50
# 1314  Q3-2020  103.8  13.75
# 1315  Q4-2020  104.8  14.00
# 1316  Q1-2021  105.3  14.25
# 1317  Q2-2021  107.2  14.50
# 1318  Q3-2021  108.2  14.75
# 1319  Q4-2021  109.5  15.00

# %%
x = G7data['yr']
y = G7data['Value']

m = stats.linregress(x, y)

t = [m.slope * i + m.intercept for i in x]
G7data.insert(len(G7data.columns),'r',t)

ax = G7data.plot.scatter(x='Period',
                         y='Value')
G7data.plot.line(x='Period',
                 y='r', 
                 color='red', 
                 ax=ax, 
                 figsize = (16,8), 
                 rot=90)

#G7data
# Out:
# <AxesSubplot:xlabel='Period', ylabel='Value'>

# %%
G7data2009 = G7data[(G7data['yr']>2) & (G7data['yr']<=8)]


x = G7data2009['yr']
y = G7data2009['Value']

m = stats.linregress(x, y)

t = [m.slope * i + m.intercept for i in G7data['yr']]

G7data.insert(len(G7data.columns),'r2',t)

ax = G7data.plot.scatter(x='Period',
                         y='Value')
ax = G7data.plot.line(x='Period',
                      y='r2', 
                      color='red', 
                      ax=ax, 
                      figsize = (16,8), 
                      rot=90)

# trained on intervening years, the model does a pretty good job of predicting up
# Q1 2021 
# 2 things - the model is useful for predicting under normal circumstances
# - but random events happen in real life that cannot be predictded

G7data
# Out:
#        Period  Value     yr           r          r2
# 1260  Q1-2007   92.4   0.25   89.317705   86.177087
# 1261  Q2-2007   92.9   0.50   89.632698   86.580826
# 1262  Q3-2007   93.2   0.75   89.947691   86.984565
# 1263  Q4-2007   93.6   1.00   90.262684   87.388304
# 1264  Q1-2008   93.7   1.25   90.577677   87.792043
# 1265  Q2-2008   93.8   1.50   90.892670   88.195783
# 1266  Q3-2008   93.1   1.75   91.207663   88.599522
# 1267  Q4-2008   91.2   2.00   91.522656   89.003261
# 1268  Q1-2009   89.1   2.25   91.837649   89.407000
# 1269  Q2-2009   89.2   2.50   92.152642   89.810739
# 1270  Q3-2009   89.4   2.75   92.467635   90.214478
