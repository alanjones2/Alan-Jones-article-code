# %%
import pandas as pd
url = 'http://api.worldbank.org/v2/country/all/indicator/SP.POP.TOTL?source=2&downloadformat=csv'

gdppercap = pd.read_csv(url,engine='python',encoding='utf-16')

gdppercap.tail()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9732/1063166196.py in <module>
#       2 url = 'http://api.worldbank.org/v2/country/all/indicator/SP.POP.TOTL?source=2&downloadformat=csv'
#       3
# ----> 4 gdppercap = pd.read_csv(url,engine='python',encoding='utf-16')
#       5
#       6 gdppercap.tail()
#
# c:\Users\jones\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
