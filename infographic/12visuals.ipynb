# %%
import pandas as pd
import matplotlib.pyplot as plt

path = "images/"

weather.plot(x='Month', y = 'Tmax', linewidth=5)
plt.savefig(f'{path}temp1.png')

weather.plot.bar(x='Month', y = 'Rain')
plt.savefig(f'{path}temp2.png')




fig, ax = plt.subplots(figsize=(10,5))

img3 = plt.imread(f'{path}temp1.png')
img2 = plt.imread(f'{path}temp2.png')

img = plt.imread(f'{path}pexels-brett-sayles-1431822.jpg')

ax.imshow(img2, aspect='auto', alpha=0.9, extent=(0,50,0,50))

ax.imshow(img3, aspect='auto', alpha=0.9, extent=(50,100,50,100))
ax.imshow(img, aspect='auto', alpha=0.5, extent=(0,100,0,100))

text = """
aefveav er gqerer e rqerg erg
ergeqrg eqrgeq g
e ge45g4ghw4thrthrh  w 4tg 4wt 
"""
ax.text(2,98, text,
        verticalalignment='top', horizontalalignment='left',
        color='blue', fontsize=12)

ax.plot([0,100],[0,100], alpha = 0)
#plt.axis('off')
