# %%
import pandas as pd

# %%
popgrowth = pd.read_csv('data/population-growth.csv')
popgrowth
# Out:
#       Country name  Year  Population growth rate
# 0      Afghanistan  1950                    1.17
# 1      Afghanistan  1951                    1.25
# 2      Afghanistan  1952                    1.27
# 3      Afghanistan  1953                    1.24
# 4      Afghanistan  1954                    1.31
# ...            ...   ...                     ...
# 18355     Zimbabwe  2017                    2.02
# 18356     Zimbabwe  2018                    2.02
# 18357     Zimbabwe  2019                    1.96
# 18358     Zimbabwe  2020                    2.10
# 18359     Zimbabwe  2021                    1.99
#
# [18360 rows x 3 columns]

# %%
worldgrowth = popgrowth[popgrowth['Country name'] == 'World']
worldgrowth
# Out:
#       Country name  Year  Population growth rate
# 18072        World  1950                    1.73
# 18073        World  1951                    1.74
# 18074        World  1952                    1.93
# 18075        World  1953                    1.90
# 18076        World  1954                    1.98
# ...            ...   ...                     ...
# 18139        World  2017                    1.13
# 18140        World  2018                    1.07
# 18141        World  2019                    1.03
# 18142        World  2020                    0.92
# 18143        World  2021                    0.82
#
# [72 rows x 3 columns]

# %%
worldgrowth.plot(x='Year', y='Population growth rate')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
popdf = pd.read_csv('data/population.csv')
worldpop = popdf[popdf['Country name'] == 'World']
worldpop
# Out:
#       Country name  Year   Population  \
# 37750        World  1950   2499322000
# 37751        World  1951   2543130400
# 37752        World  1952   2590271000
# 37753        World  1953   2640278800
# 37754        World  1954   2691979300
# ...            ...   ...          ...
# 37896        World  2096  10388517000
# 37897        World  2097  10379889000
# 37898        World  2098  10370445000
# 37899        World  2099  10360270000
# 37900        World  2100  10349323000
#
#        Population of children under the age of 1  \
# 37750                                 81711670.0
# 37751                                 83458900.0
# 37752                                 86144744.0
# 37753                                 88318760.0
# 37754                                 89850344.0
# ...                                          ...
# 37896                                112761060.0
# 37897                                112237210.0
# 37898                                111733864.0
# ...

# %% [markdown]
# ### World population projection

# %%
worldpop.plot(x='Year',y='Population')
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# ### India will overtake China as most the populous country

# %%
ax = popdf[popdf['Country name'] == 'India'].plot(x='Year',y='Population', label = 'India')
popdf[popdf['Country name'] == 'China'].plot(x='Year',y='Population',ax=ax, label="China")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
popgrowth = pd.read_csv('data/population-growth.csv')
popgrowth
# Out:
#       Country name  Year  Population growth rate
# 0      Afghanistan  1950                    1.17
# 1      Afghanistan  1951                    1.25
# 2      Afghanistan  1952                    1.27
# 3      Afghanistan  1953                    1.24
# 4      Afghanistan  1954                    1.31
# ...            ...   ...                     ...
# 18355     Zimbabwe  2017                    2.02
# 18356     Zimbabwe  2018                    2.02
# 18357     Zimbabwe  2019                    1.96
# 18358     Zimbabwe  2020                    2.10
# 18359     Zimbabwe  2021                    1.99
#
# [18360 rows x 3 columns]

# %%
worldgrowth = popgrowth[popgrowth['Country name'] == 'World']
worldgrowth
# Out:
#       Country name  Year  Population growth rate
# 18072        World  1950                    1.73
# 18073        World  1951                    1.74
# 18074        World  1952                    1.93
# 18075        World  1953                    1.90
# 18076        World  1954                    1.98
# ...            ...   ...                     ...
# 18139        World  2017                    1.13
# 18140        World  2018                    1.07
# 18141        World  2019                    1.03
# 18142        World  2020                    0.92
# 18143        World  2021                    0.82
#
# [72 rows x 3 columns]

# %%
worldgrowth.plot(x='Year', y='Population growth rate')
# Out:
# <AxesSubplot:xlabel='Year'>
