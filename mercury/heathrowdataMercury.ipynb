# %% [raw]
# ---
# title: Exploring London Weather Data
# description: How to use mercury to create a web app from a Jupyter notebook
# show-code: False
# params:
#     year:
#         input: slider
#         label: Select year
#         value: 1952
#         min: 1952
#         max: 2018
# ---

# %%
year = 1962

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# Change 'default' to the style that you want to try out
matplotlib.style.use('dark_background')

# %% [markdown]
# # Exploring London Weather Data

# %%
import numpy as np
import pandas as pd

# %%
weather=pd.read_csv('heathrowDataFiltered.csv')

# %%
weather[weather['Year']==year].plot(y='Tmax', x='Month', legend=False, figsize=(10,5))

print(f"Monthly maximum temperatures for {year}")
# Out:
# Monthly maximum temperatures for 1962
